# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
from scipy.stats import norm

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
assesment_data_dummy_asses = pd.read_csv("Cleaned_Book2.csv")
assesment_data_dummy_asses = pd.DataFrame(assesment_data_dummy_asses)

# %%
assesment_data = pd.read_csv("Cleaned_Book.csv")
assesment_data = pd.DataFrame(assesment_data)

# %%
assesment_data["data2.Assessment"].unique()
# Out:
# array(['Mathematics', 'English Language Arts', 'Science'], dtype=object)

# %%
assesment_data_dummy_asses.head()
# Out:
#    Unnamed: 0      data2.District.Name          data2.School.Name  \
# 0       62959  Lewiston Public Schools  Farwell Elementary School
# 1       62960  Lewiston Public Schools  Farwell Elementary School
# 2       62961  Lewiston Public Schools  Farwell Elementary School
# 3       62962  Lewiston Public Schools  Farwell Elementary School
# 4       62963  Lewiston Public Schools  Farwell Elementary School
#
#                             data2.Population      data2.Disaggregated  \
# 0                 Economically Disadvantaged                    Other
# 1                  Black or African American  Racial/Ethnic Diversity
# 2                               All Students             All Students
# 3  Native Hawaiian or Other Pacific Islander  Racial/Ethnic Diversity
# 4                                      Asian  Racial/Ethnic Diversity
#
#   data2.Assessment  data2.Achievement.Level
# 0      Mathematics                      0.0
# 1      Mathematics                      0.0
# ...

# %%
assesment_data.head()
# Out:
#    Unnamed: 0      data2.District.Name          data2.School.Name  \
# 0       62959  Lewiston Public Schools  Farwell Elementary School
# 1       62960  Lewiston Public Schools  Farwell Elementary School
# 2       62961  Lewiston Public Schools  Farwell Elementary School
# 3       62962  Lewiston Public Schools  Farwell Elementary School
# 4       62963  Lewiston Public Schools  Farwell Elementary School
#
#                             data2.Population      data2.Disaggregated  \
# 0                 Economically Disadvantaged                    Other
# 1                  Black or African American  Racial/Ethnic Diversity
# 2                               All Students             All Students
# 3  Native Hawaiian or Other Pacific Islander  Racial/Ethnic Diversity
# 4                                      Asian  Racial/Ethnic Diversity
#
#   data2.Assessment        data2.Achievement.Level
# 0      Mathematics  Well Below State Expectations
# ...

# %%
assesment_data = assesment_data.drop("Unnamed: 0", axis=1)
assesment_data = assesment_data.drop("data2.District.Name", axis=1)
assesment_data_dummy_asses = assesment_data_dummy_asses.drop("Unnamed: 0", axis=1)
assesment_data_dummy_asses = assesment_data_dummy_asses.drop("data2.District.Name", axis=1)

# %%
assesment_data.head()
# Out:
#            data2.School.Name                           data2.Population  \
# 0  Farwell Elementary School                 Economically Disadvantaged
# 1  Farwell Elementary School                  Black or African American
# 2  Farwell Elementary School                               All Students
# 3  Farwell Elementary School  Native Hawaiian or Other Pacific Islander
# 4  Farwell Elementary School                                      Asian
#
#        data2.Disaggregated data2.Assessment        data2.Achievement.Level
# 0                    Other      Mathematics  Well Below State Expectations
# 1  Racial/Ethnic Diversity      Mathematics  Well Below State Expectations
# 2             All Students      Mathematics  Well Below State Expectations
# 3  Racial/Ethnic Diversity      Mathematics  Well Below State Expectations
# 4  Racial/Ethnic Diversity      Mathematics  Well Below State Expectations

# %%
assesment_data_dummy_asses.head()
# Out:
#            data2.School.Name                           data2.Population  \
# 0  Farwell Elementary School                 Economically Disadvantaged
# 1  Farwell Elementary School                  Black or African American
# 2  Farwell Elementary School                               All Students
# 3  Farwell Elementary School  Native Hawaiian or Other Pacific Islander
# 4  Farwell Elementary School                                      Asian
#
#        data2.Disaggregated data2.Assessment  data2.Achievement.Level
# 0                    Other      Mathematics                      0.0
# 1  Racial/Ethnic Diversity      Mathematics                      0.0
# 2             All Students      Mathematics                      0.0
# 3  Racial/Ethnic Diversity      Mathematics                      0.0
# 4  Racial/Ethnic Diversity      Mathematics                      0.0

# %%
from sklearn.ensemble import RandomForestClassifier

y = assesment_data_dummy_asses["data2.Achievement.Level"]

features = ["data2.School.Name", "data2.Population", "data2.Disaggregated", "data2.Assessment"]
X = pd.get_dummies(assesment_data[features], prefix='', prefix_sep='')

# %%
assesment_data[features].head()
# Out:
#            data2.School.Name                           data2.Population  \
# 0  Farwell Elementary School                 Economically Disadvantaged
# 1  Farwell Elementary School                  Black or African American
# 2  Farwell Elementary School                               All Students
# 3  Farwell Elementary School  Native Hawaiian or Other Pacific Islander
# 4  Farwell Elementary School                                      Asian
#
#        data2.Disaggregated data2.Assessment
# 0                    Other      Mathematics
# 1  Racial/Ethnic Diversity      Mathematics
# 2             All Students      Mathematics
# 3  Racial/Ethnic Diversity      Mathematics
# 4  Racial/Ethnic Diversity      Mathematics

# %%
X.head()
# Out:
#    Farwell Elementary School  Governor James B Longley Elem Sch  \
# 0                          1                                  0
# 1                          1                                  0
# 2                          1                                  0
# 3                          1                                  0
# 4                          1                                  0
#
#    Lewiston High School  Lewiston Middle School  Martel School  \
# 0                     0                       0              0
# 1                     0                       0              0
# 2                     0                       0              0
# 3                     0                       0              0
# 4                     0                       0              0
#
#    Montello School  Raymond A. Geiger Elementary School  \
# 0                0                                    0
# 1                0                                    0
# ...

# %%
#= assesment_data.rename(columns={"A": "a", "B": "c"}
features = ["data2.School.Name", "data2.Population", "data2.Disaggregated", "data2.Assessment", "data2.Achievement.Level"]
X = pd.get_dummies(assesment_data[features], prefix='', prefix_sep='')
corrmat1 = X.corr()
corrmat1
  
f, ax = plt.subplots(figsize =(5, 5)) 
sns.heatmap(corrmat1, ax = ax, cmap ="YlGnBu", linewidths = 0.1, center = 0, vmin=-1, vmax=1)#, annot=True, annot_kws={"size": 3})
ax.set_title('Lewiston Public School ESAU Data Heat Map', fontsize=20)
plt.show()

# %%
features = ["data2.School.Name", "data2.Population", "data2.Disaggregated", "data2.Assessment"]
X = pd.get_dummies(assesment_data_dummy_asses[features])
final_data = pd.concat([X, y], axis=1)
corrmat2 = final_data.corr()
corrmat2
  
f, ax = plt.subplots(figsize =(5, 5)) 
sns.heatmap(corrmat2, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
#WE could remove some to improve the relationship?
X = X.drop("data2.School.Name_Montello School", axis = 1)
X = X.drop("data2.Population_All Students", axis = 1)
X = X.drop("data2.Disaggregated_All Students", axis = 1)
X = X.drop("data2.Assessment_English Language Arts", axis = 1)

# %%
s1 = pd.Series(y, name='Achievement.Level')

result = pd.concat([X, y], axis=1)
official_data = result

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(official_data['data2.Achievement.Level'])

# %%
official_data.isnull().any()
# Out:
# data2.School.Name_Farwell Elementary School                   False
# data2.School.Name_Governor James B Longley Elem Sch           False
# data2.School.Name_Lewiston High School                        False
# data2.School.Name_Lewiston Middle School                      False
# data2.School.Name_Martel School                               False
# data2.School.Name_Raymond A. Geiger Elementary School         False
# data2.School.Name_Thomas J McMahon Elementary Sch             False
# data2.Population_American Indian or Alaska Native             False
# data2.Population_Asian                                        False
# data2.Population_Black or African American                    False
# data2.Population_Economically Disadvantaged                   False
# data2.Population_English Learners                             False
# data2.Population_English Learners (Monitoring)                False
# data2.Population_Female                                       False
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# <h3>
#     Linear Regression
# </h3>

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
acc_linregressor = round(regressor.score(X_train, y_train) * 100, 2)
acc_linregressor
# Out:
# 0.07

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                                      Coefficient
# data2.School.Name_Farwell Elementary School        -1.286773e-02
# data2.School.Name_Governor James B Longley Elem... -3.432363e-04
# data2.School.Name_Lewiston High School             -7.335840e-03
# data2.School.Name_Lewiston Middle School            4.395876e-03
# data2.School.Name_Martel School                    -6.026286e-03
# data2.School.Name_Raymond A. Geiger Elementary ...  4.182492e-03
# data2.School.Name_Thomas J McMahon Elementary Sch  -3.884706e-02
# data2.Population_American Indian or Alaska Native   1.024843e+13
# data2.Population_Asian                              1.024843e+13
# data2.Population_Black or African American          1.024843e+13
# data2.Population_Economically Disadvantaged         1.588928e+13
# data2.Population_English Learners                   1.588928e+13
# data2.Population_English Learners (Monitoring)      1.588928e+13
# ...

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)
df1
# Out:
#       Actual  Predicted
# 5091     0.5   1.461507
# 3294     3.0   1.492757
# 6629     0.0   1.574960
# 1775     2.5   1.498616
# 1633     2.5   1.585702
# 134      2.0   1.588632
# 1029     0.5   1.525960
# 3682     0.5   1.461361
# 6917     2.0   1.594491
# 6586     3.0   1.467538
# 2090     1.0   1.492335
# 6153     0.5   1.531991
# 5048     2.0   1.502522
# 4321     1.0   1.412678
# 1437     3.0   1.471444
# 4194     3.0   1.424569
# 982      2.0   1.463936
# 6846     3.0   1.487546
# 4410     3.0   1.505663
# 776      0.0   1.516366
# 3081     0.0   1.432382
# 543      2.0   1.475351
# 5767     0.0   1.508382
# 162      2.5   1.485116
# 3267     1.0   1.568928

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.0071423429265647
# Mean Squared Error: 1.1860453902129715
# Root Mean Squared Error: 1.089057110629636

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
score
# Out:
# -0.010276607144934058

# %% [markdown]
# <h3>
#     Random Forest Classifier
# </h3>

# %%
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LogisticRegression
from sklearn import preprocessing
from sklearn import utils

# %%
from sklearn.ensemble import RandomForestClassifier

lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
print(training_scores_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
print(utils.multiclass.type_of_target(training_scores_encoded))

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X_train, training_scores_encoded)

predictions = model.predict(X_test)

model.score(X_train, training_scores_encoded)
acc_random_forest = round(model.score(X_train, training_scores_encoded) * 100, 2)
acc_random_forest

#print(predictions)
# Out:
# [3 0 2 ... 0 4 0]
# continuous
# multiclass
# multiclass
# 20.02

# %%
y_pred = model.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)
df1
# Out:
#       Actual  Predicted
# 5091     0.5          0
# 3294     3.0          4
# 6629     0.0          5
# 1775     2.5          2
# 1633     2.5          5
# 134      2.0          5
# 1029     0.5          5
# 3682     0.5          1
# 6917     2.0          1
# 6586     3.0          1
# 2090     1.0          5
# 6153     0.5          3
# 5048     2.0          0
# 4321     1.0          2
# 1437     3.0          2
# 4194     3.0          2
# 982      2.0          2
# 6846     3.0          1
# 4410     3.0          4
# 776      0.0          5
# 3081     0.0          1
# 543      2.0          4
# 5767     0.0          2
# 162      2.5          3
# 3267     1.0          5

# %%
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',                                                                 ascending=False)
print(feature_importances)
# Out:
#                                                     importance
# data2.Assessment_Science                              0.146982
# data2.Assessment_Mathematics                          0.145490
# data2.School.Name_Lewiston Middle School              0.058638
# data2.School.Name_Lewiston High School                0.052878
# data2.School.Name_Raymond A. Geiger Elementary ...    0.050786
# data2.School.Name_Thomas J McMahon Elementary Sch     0.048196
# data2.School.Name_Martel School                       0.046686
# data2.School.Name_Governor James B Longley Elem...    0.045765
# data2.School.Name_Farwell Elementary School           0.036835
# data2.Population_Homeless                             0.033970
# data2.Population_Hispanic or Latino                   0.024063
# data2.Population_Parent in Military on Active Duty    0.023710
# data2.Population_Black or African American            0.022062
# data2.Population_English Learners (Monitoring)        0.020932
# ...

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.0182682682682684
# Mean Squared Error: 5.972347347347347
# Root Mean Squared Error: 2.4438386500232268

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
score
# Out:
# -4.08726130092347

# %% [markdown]
# <h3>
#     Logistic Regression
# </h3>

# %%
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
print(training_scores_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
print(utils.multiclass.type_of_target(training_scores_encoded))
# Out:
# [3 0 2 ... 0 4 0]
# continuous
# multiclass
# multiclass

# %%
logreg = LogisticRegression()
logreg.fit(X_train, training_scores_encoded)
print("LogisticRegression")
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, training_scores_encoded) * 100, 2)
print(acc_log ,"% correctnesss")
# Out:
# LogisticRegression
# 18.3 % correctnesss

# %%
coeff_df = pd.DataFrame(X.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#                                               Feature  Correlation
# 19           data2.Population_Students in Foster Care     0.076725
# 27                           data2.Assessment_Science     0.073324
# 4   data2.School.Name_Raymond A. Geiger Elementary...     0.070297
# 14                          data2.Population_Homeless     0.061944
# 11     data2.Population_English Learners (Monitoring)     0.054896
# 18  data2.Population_Parent in Military on Active ...     0.050453
# 3                     data2.School.Name_Martel School     0.049403
# 8          data2.Population_Black or African American     0.040931
# 5   data2.School.Name_Thomas J McMahon Elementary Sch     0.037043
# 10                  data2.Population_English Learners     0.036086
# 6   data2.Population_American Indian or Alaska Native     0.015995
# 16                           data2.Population_Migrant     0.015156
# 12                            data2.Population_Female     0.011196
# ...

# %%
y_pred = logreg.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)
df1
# Out:
#       Actual  Predicted
# 5091     0.5          0
# 3294     3.0          0
# 6629     0.0          5
# 1775     2.5          0
# 1633     2.5          5
# 134      2.0          5
# 1029     0.5          5
# 3682     0.5          1
# 6917     2.0          5
# 6586     3.0          1
# 2090     1.0          0
# 6153     0.5          5
# 5048     2.0          0
# 4321     1.0          2
# 1437     3.0          2
# 4194     3.0          2
# 982      2.0          1
# 6846     3.0          1
# 4410     3.0          5
# 776      0.0          5
# 3081     0.0          0
# 543      2.0          4
# 5767     0.0          2
# 162      2.5          3
# 3267     1.0          0

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.08033033033033
# Mean Squared Error: 6.44481981981982
# Root Mean Squared Error: 2.5386649680136646

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
score
# Out:
# -4.489714605322854

# %% [markdown]
# <h3>
#     SVC: Support Vector Machines
# </h3>

# %%
# Support Vector Machines

svc = SVC()
svc.fit(X_train, training_scores_encoded)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, training_scores_encoded) * 100, 2)
acc_svc
# Out:
# 20.45

# %% [markdown]
# <h3>
#     KNN: k-Nearest Neighbors
# </h3>

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, training_scores_encoded)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, training_scores_encoded) * 100, 2)
acc_knn
# Out:
# 17.98

# %% [markdown]
# <h3>
#     Gaussian Naive Bayes
# </h3>

# %%
# Gaussian Naive Bayes

gaussian = GaussianNB()
gaussian.fit(X_train, training_scores_encoded)
Y_pred = gaussian.predict(X_test)
acc_gaussian = round(gaussian.score(X_train, training_scores_encoded) * 100, 2)
acc_gaussian
# Out:
# 18.05

# %% [markdown]
# <h3>
#     Perceptron
# </h3>

# %%
# Perceptron

perceptron = Perceptron()
perceptron.fit(X_train, training_scores_encoded)
Y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train, training_scores_encoded) * 100, 2)
acc_perceptron
# Out:
# 16.87

# %% [markdown]
# <h3>
#     Linear SVC
# </h3>

# %%
# Linear SVC

linear_svc = LinearSVC()
linear_svc.fit(X_train, training_scores_encoded)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train, training_scores_encoded) * 100, 2)
acc_linear_svc
# Out:
# 18.22

# %% [markdown]
# <h3>
#     Stochastic Gradient Descent
# </h3>

# %%
# Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(X_train, training_scores_encoded)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train, training_scores_encoded) * 100, 2)
acc_sgd
# Out:
# 16.9

# %% [markdown]
# <h3>
#     Decision Tree
# </h3>

# %%
# Decision Tree

decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, training_scores_encoded)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, training_scores_encoded) * 100, 2)
acc_decision_tree
# Out:
# 21.79

# %%
y_pred = decision_tree.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.sample(20)
df1
# Out:
#       Actual  Predicted
# 5689     0.0          3
# 5830     2.5          5
# 5752     0.5          2
# 2525     2.5          2
# 4889     2.0          2
# 1601     1.0          1
# 6294     2.5          2
# 5803     2.0          1
# 558      3.0          0
# 4324     1.0          3
# 842      2.5          1
# 7162     3.0          1
# 7048     0.0          1
# 5332     0.5          0
# 4941     0.0          1
# 2306     2.5          0
# 7971     2.5          3
# 4004     2.0          0
# 4846     0.5          0
# 3184     1.0          0

# %%
import pandas as pd
feature_importances = pd.DataFrame(decision_tree.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',                                                                 ascending=False)
print(feature_importances)
print(sum(feature_importances["importance"]))
# Out:
#                                                     importance
# data2.School.Name_Raymond A. Geiger Elementary ...    0.101748
# data2.School.Name_Lewiston Middle School              0.089141
# data2.School.Name_Farwell Elementary School           0.085809
# data2.Assessment_Science                              0.084465
# data2.School.Name_Governor James B Longley Elem...    0.067006
# data2.School.Name_Martel School                       0.043458
# data2.Population_American Indian or Alaska Native     0.037580
# data2.School.Name_Lewiston High School                0.032870
# data2.Population_Asian                                0.032803
# data2.Disaggregated_Racial/Ethnic Diversity           0.032614
# data2.Population_Two or More Races                    0.031350
# data2.Population_Black or African American            0.030512
# data2.Population_Students in Foster Care              0.029520
# data2.Population_Economically Disadvantaged           0.028409
# ...

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('Lewiston Public School Decision Tree Predictive Model on Random Sample Size of 20', fontsize=20)
plt.xlabel("Characteristic Combinations Identified by their Order in the Data Set")
plt.ylabel("Achievement Level Score")
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.666916916916917
# Mean Squared Error: 4.040415415415415
# Root Mean Squared Error: 2.0100784600147863

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
score
# Out:
# -2.4416365604768338

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree', 'Linear Regression'],
    'Score': [acc_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree, acc_linregressor]})
models.sort_values(by='Score', ascending=False)
# Out:
#                         Model  Score
# 8               Decision Tree  21.79
# 0     Support Vector Machines  20.45
# 3               Random Forest  20.02
# 2         Logistic Regression  18.30
# 7                  Linear SVC  18.22
# 4                 Naive Bayes  18.05
# 1                         KNN  17.98
# 6  Stochastic Gradient Decent  16.90
# 5                  Perceptron  16.87
# 9           Linear Regression   0.07
